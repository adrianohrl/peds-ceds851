# %%
import pandas as pd

# %%
df = pd.read_pickle('../datasets/andamentos_tjsp.pkl')
df
# Out:
#                                 Processo       data  \
# 123557  218a98942855ddf259f6ea0bee343b67 1973-05-17
# 128428  4bf8c065bc0f776b3598c3990b9ed8c0 1979-09-10
# 97535   a9b501b6b76a7eff441ebf5d9c3ec872 1980-04-30
# 131228  2fdc177c5ec4f2e2743ac65e0cefd0e4 1980-11-28
# 143392  09e89309dde68184c0c4997f19691668 1990-02-13
# 143393  09e89309dde68184c0c4997f19691668 1990-03-15
# 143394  09e89309dde68184c0c4997f19691668 1990-03-27
# 143395  09e89309dde68184c0c4997f19691668 1990-04-02
# 143396  09e89309dde68184c0c4997f19691668 1990-04-04
# 143397  09e89309dde68184c0c4997f19691668 1990-04-05
# 143398  09e89309dde68184c0c4997f19691668 1990-04-11
# 143399  09e89309dde68184c0c4997f19691668 1991-07-22
# 143400  09e89309dde68184c0c4997f19691668 1993-07-12
# 143401  09e89309dde68184c0c4997f19691668 1993-07-15
# 143402  09e89309dde68184c0c4997f19691668 1993-08-12
# 143403  09e89309dde68184c0c4997f19691668 1993-10-26
# 143404  09e89309dde68184c0c4997f19691668 1993-11-04
# ...

# %%
df[['descricao', 'timedelta']].to_csv('../datasets/andamentos_tjsp.csv')

# %%
df = pd.read_csv('../datasets/andamentos_tjsp.csv', index_col = 0)
df
# Out:
#                                                 descricao  timedelta
# 123557  Distribuição Livre Conforme remessa ao Distrib...    11079.0
# 128428  Distribuído por Direcionamento (movimentação e...    13534.0
# 97535   Distribuído por Direcionamento (movimentação e...    12375.0
# 131228  Distribuição Livre Processo Distribuído por So...     8859.0
# 143392  Incidente Processual Incidente Processual 583....       30.0
# 143393  Incidente Processual Incidente Processual 583....       12.0
# 143394  Incidente Processual Incidente Processual 583....        6.0
# 143395  Incidente Processual Incidente Processual 583....        2.0
# 143396  Incidente Processual Incidente Processual 583....        1.0
# 143397  Incidente Processual Incidente Processual 583....        6.0
# 143398  Incidente Processual Incidente Processual 583....      467.0
# 143399  Incidente Processual Incidente Processual 583....      721.0
# 143400  Incidente Processual Incidente Processual 583....        3.0
# ...
